# %%
# Kết nối đến Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import numpy as np
import os
from google.colab.patches import cv2_imshow

# %%
path = '/content/drive/MyDrive/test_opencv'
# Hiển thị tất cả thư mục hoặc file
os.listdir(path)
# Out:
# ['02.jpg',
#  'image_20.jpg',
#  'image_40.jpg',
#  'image_60.jpg',
#  'image_80.jpg',
#  'image_100.jpg',
#  'image_120.jpg',
#  'image_140.jpg',
#  'image_160.jpg',
#  'image_180.jpg',
#  'image_220.jpg',
#  'image_200.jpg',
#  'image_240.jpg',
#  'image_260.jpg',
#  'image_280.jpg',
#  'image_300.jpg',
#  'image_340.jpg',
#  'image_320.jpg',
#  'image_360.jpg',
#  'image_380.jpg',
#  'image_400.jpg',
#  'image_420.jpg',
#  'image_440.jpg',
#  'image_460.jpg',
#  'image_480.jpg',
#  'image_520.jpg',
#  'image_500.jpg',
#  'image_540.jpg',
#  'image_560.jpg',
#  'image_580.jpg',
#  'image_600.jpg',
#  'image_640.jpg',
#  'image_620.jpg',
#  'image_660.jpg',
#  'image_680.jpg',
#  'image_700.jpg',
#  'image_720.jpg',
#  'image_760.jpg',
#  'image_740.jpg',
#  'image_780.jpg',
#  'image_820.jpg',
#  'image_800.jpg',
#  'image_840.jpg',
#  'image_860.jpg',
#  'image_880.jpg',
#  'image_900.jpg',
#  'image_920.jpg',
#  'image_940.jpg',
#  'image_960.jpg',
#  'image_1000.jpg',
#  'image_980.jpg',
#  'image_1020.jpg',
#  'image_1060.jpg',
#  'image_1040.jpg',
#  'image_1080.jpg',
#  'image_1120.jpg',
#  'image_1100.jpg',
#  'image_1140.jpg',
#  'image_1160.jpg',
#  'image_1180.jpg',
#  'image_1200.jpg',
#  'image_1220.jpg',
#  'image_1240.jpg',
#  'image_1260.jpg',
#  'image_1280.jpg',
#  'image_1300.jpg',
#  'image_1320.jpg',
#  'image_1340.jpg',
#  'image_1360.jpg',
#  'image_1380.jpg',
#  'image_1400.jpg',
#  'image_1420.jpg',
#  'image_1440.jpg',
#  'image_1480.jpg',
#  'image_1460.jpg',
#  'models',
#  'Bai27.ipynb',
#  '30.ipynb',
#  'FaceImage',
#  'data_face_features.pickle',
#  'Bai31.ipynb']

# %%
# Hiển thị một ảnh
img = cv2.imread(path + "/image_1460.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
