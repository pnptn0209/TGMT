# %%
from PIL import Image
from imgtools import *

# %%
my_dir = r'C:/01'

# %%
imgs = get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (275, 183)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>
# (266, 190)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=266x190>
# (259, 194)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194>
# (299, 168)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=299x168>
# (612, 406)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x406>
